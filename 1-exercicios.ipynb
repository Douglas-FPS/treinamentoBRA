# %% [markdown]
# ### 1. Ler e exibir um arquivo CSV usando pandas

# %%
import pandas as pd
import numpy as np 

df = spark.read.csv("/FileStore/tables/retail.csv", header=True, sep=',')
df = df.toPandas()

# %%
df.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>invoiceno</th>
#       <th>stockcode</th>
#       <th>description</th>
#       <th>quantity</th>
#       <th>invoicedate</th>
#       <th>unitprice</th>
#       <th>customer_id</th>
#       <th>region</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>536365</td>
#       <td>85123A</td>
#       <td>WHITE HANGING HEART T-LIGHT HOLDER</td>
#       <td>6</td>
#       <td>12/1/10 8:26</td>
#       <td>2,55</td>
#       <td>17850</td>
#       <td>United Kingdom</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>536365</td>
#       <td>71053</td>
#       <td>WHITE METAL LANTERN</td>
#       <td>6</td>
#       <td>12/1/10 8:26</td>
#       <td>3,39</td>
#       <td>17850</td>
#       <td>United Kingdom</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>536365</td>
#       <td>84406B</td>
#       <td>CREAM CUPID HEARTS COAT HANGER</td>
#       <td>8</td>
#       <td>12/1/10 8:26</td>
#       <td>2,75</td>
#       <td>17850</td>
#       <td>United Kingdom</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>536365</td>
#       <td>84029G</td>
#       <td>KNITTED UNION FLAG HOT WATER BOTTLE</td>
#       <td>6</td>
#       <td>12/1/10 8:26</td>
#       <td>3,39</td>
#       <td>17850</td>
#       <td>United Kingdom</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>536365</td>
#       <td>84029E</td>
#       <td>RED WOOLLY HOTTIE WHITE HEART.</td>
#       <td>6</td>
#       <td>12/1/10 8:26</td>
#       <td>3,39</td>
#       <td>17850</td>
#       <td>United Kingdom</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# ### 2. Selecionar colunas específicas de um DataFrame usando pandas

# %%
df_2 = df.filter(['invoiceno', 'quantity'])
df_2
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>invoiceno</th>
#       <th>quantity</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>536365</td>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>536365</td>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>536365</td>
#       <td>8</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>536365</td>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>536365</td>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>541904</th>
#       <td>581587</td>
#       <td>12</td>
#     </tr>
#     <tr>
#       <th>541905</th>
#       <td>581587</td>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>541906</th>
#       <td>581587</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>541907</th>
#       <td>581587</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>541908</th>
#       <td>581587</td>
#       <td>3</td>
#     </tr>
#   </tbody>
# </table>
# <p>541909 rows × 2 columns</p>
# </div>

# %% [markdown]
# ### 3. Filtrar linhas com base em uma condição usando pandas

# %%
df.query('invoiceno == "536368"') #aspas simples envolvendo a condição
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>invoiceno</th>
#       <th>stockcode</th>
#       <th>description</th>
#       <th>quantity</th>
#       <th>invoicedate</th>
#       <th>unitprice</th>
#       <th>customer_id</th>
#       <th>region</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>21</th>
#       <td>536368</td>
#       <td>22960</td>
#       <td>JAM MAKING SET WITH JARS</td>
#       <td>6</td>
#       <td>12/1/10 8:34</td>
#       <td>4,25</td>
#       <td>13047</td>
#       <td>United Kingdom</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>536368</td>
#       <td>22913</td>
#       <td>RED COAT RACK PARIS FASHION</td>
#       <td>3</td>
#       <td>12/1/10 8:34</td>
#       <td>4,95</td>
#       <td>13047</td>
#       <td>United Kingdom</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>536368</td>
#       <td>22912</td>
#       <td>YELLOW COAT RACK PARIS FASHION</td>
#       <td>3</td>
#       <td>12/1/10 8:34</td>
#       <td>4,95</td>
#       <td>13047</td>
#       <td>United Kingdom</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>536368</td>
#       <td>22914</td>
#       <td>BLUE COAT RACK PARIS FASHION</td>
#       <td>3</td>
#       <td>12/1/10 8:34</td>
#       <td>4,95</td>
#       <td>13047</td>
#       <td>United Kingdom</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# ### 4. Agrupar dados com base em uma coluna usando pandas

# %%
df.groupby('invoiceno')['quantity'].sum()
# Out:
# Out[32]: invoiceno
# 536365           6686626
# 536366                66
# 536367     3266866323344
# 536368              6333
# 536369                 3
#                ...
# C581484           -80995
# C581490           -12-11
# C581499               -1
# C581568               -5
# C581569             -1-5
# Name: quantity, Length: 25900, dtype: object

# %% [markdown]
# ### 5. Usar a função max em alguma coluna do DataFrame

# %%
df['quantity'].max()
# Out:
# Out[28]: '992'
